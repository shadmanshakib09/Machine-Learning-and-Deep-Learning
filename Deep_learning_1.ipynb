# %% [markdown]
# <a href="https://colab.research.google.com/github/shadmanshakib09/Deep-Learning/blob/main/Deep_learning_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PERCEPTRON BASIC 01

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Number of data points
n = 100

# Generate random humidity and temperature values for two classes
humidity_class_0 = np.random.uniform(10, 30, n//2)
temperature_class_0 = np.random.uniform(60, 80, n//2)

humidity_class_1 = np.random.uniform(30, 50, n//2)
temperature_class_1 = np.random.uniform(80, 100, n//2)

# Create the labels
rain_class_0 = np.zeros(n//2)
rain_class_1 = np.ones(n//2)

# Combine the classes
humidity = np.concatenate([humidity_class_0, humidity_class_1])
temperature = np.concatenate([temperature_class_0, temperature_class_1])
rain = np.concatenate([rain_class_0, rain_class_1])

# Create a DataFrame
df = pd.DataFrame({
    'humidity': humidity,
    'temperature': temperature,
    'rain': rain.astype(int)
})

# %%
df
# Out:
#      humidity  temperature  rain
# 0   19.134487    72.759999     0
# 1   13.664363    78.131100     0
# 2   13.039133    79.665244     0
# 3   14.383691    77.685863     0
# 4   14.696133    72.811556     0
# ..        ...          ...   ...
# 95  46.930734    85.292362     1
# 96  46.027926    83.315487     1
# 97  44.175822    85.941644     1
# 98  43.576815    90.557027     1
# 99  42.052328    88.099891     1
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(data=df, x='humidity', y='temperature', hue='rain')
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %%
X = df.drop('rain', axis=1)
y = df['rain']

# %%
X.head()
# Out:
#     humidity  temperature
# 0  19.134487    72.759999
# 1  13.664363    78.131100
# 2  13.039133    79.665244
# 3  14.383691    77.685863
# 4  14.696133    72.811556

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.linear_model import Perceptron

# %%
p = Perceptron(random_state=1)
p.fit(X, y)
# Out:
# Perceptron(random_state=1)

# %%
p.score(X, y)
# Out:
# 0.59

# %%
p.coef_
# Out:
# array([[ 568.55763175, -120.46275752]])

# %%
p.intercept_
# Out:
# array([-50.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values, y.values, clf=p, legend = 2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
